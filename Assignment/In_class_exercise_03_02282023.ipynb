# %% [markdown]
# <a href="https://colab.research.google.com/github/renuchaurasia/renu_INFO5731_Spring2023/blob/main/Assignment/In_class_exercise_03_02282023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (2/28/2023, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand text representation.

# %% [markdown]
# Question 1 (10 points): Describe an interesting text classification or text mining task and explain what kind of features might be useful for you to build the machine learning model. List your features and explain why these features might be helpful. You need to list at least five different types of features.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

One of the most common tasks is to classify text documents into different categories or topics. 
One application of this is in the news industry, where there is often a need to quickly sort through a large volume 
of news articles and categorize them by topic. 

For example, a news organization may want to categorize all the articles they publish into topics like politics, sports, 
entertainment, business, and so on. This allows them to present the news in a more organized and easily accessible way for 
their readers or viewers.

To accomplish this task, text mining techniques such as natural language processing (NLP) and machine learning are used. 
These techniques can analyze the content of news articles and identify features that are specific to certain topics, 
such as keywords, named entities, co-occurring words, part-of-speech tags, and text embeddings. 
By training a machine learning model on a set of labeled news articles, we can teach the model to recognize these features and 
automatically classify new articles into the appropriate topic category.

Overall, text mining techniques have practical applications in the news industry and can help to automate the process of 
categorizing news articles into different topics, which can save time and resources for news organizations.

Bag-of-words: A bag-of-words representation captures the frequency of each word in the article. 
This feature can be useful in identifying keywords that are associated with a particular topic. 
For example, articles about sports may include words like "game," "team," and "player," while articles about politics may include words like "government," "policy," and "election."

Named entities: Named entities are words or phrases that refer to specific people, places, or things. By including named entities as features, 
we can capture important information about the topic of the article, such as the names of politicians or the locations of events. 
For example, an article that mentions "Donald Trump" is likely to be about politics, while an article that mentions "LeBron James" is likely to be about sports.

Part-of-speech tags: Part-of-speech (POS) tags are labels that indicate the syntactic category of each word in the text. 
By including POS tags as features, we can capture the grammatical structure of the text, which can be useful in identifying the topic of the article. 
For example, articles about politics may include more nouns and adjectives related to policies and legislation, 
while articles about sports may include more verbs related to athletic performance.

ngrams: In the context of news article classification, we can use ngrams as features to capture more information about the language used in news articles. 
For example, we could use bigrams or trigrams to capture more nuanced information about the topic or content of the article. 
This could help us differentiate between similar-sounding topics, such as "politics" and "political scandals," or between different genres of entertainment news, 
such as "celebrity gossip" and "movie reviews."

sentiment lexicons: While sentiment analysis might not be as relevant for news article classification as it is for product reviews, 
there are still some cases where sentiment analysis could be useful. For example, we could use sentiment lexicons to identify news articles that have a positive or 
negative sentiment towards a particular politician, policy, or event. This could help us identify biased or opinion-based news articles that might not be appropriate for 
certain use cases.

punctuation: Punctuation could also be useful for news article classification, especially in cases where the tone or intent of the article is important. 
For example, the presence of exclamation marks or question marks could indicate a more opinionated or emotional tone. The frequency of certain punctuation marks, 
such as colons or semicolons, could indicate more complex or technical writing styles, which might be more appropriate for certain categories of news, such as science or technology.


'''
# Out:
# '\nPlease write you answer here:\n\nOne of the most common tasks is to classify text documents into different categories or topics. \nOne application of this is in the news industry, where there is often a need to quickly sort through a large volume \nof news articles and categorize them by topic. \n\nFor example, a news organization may want to categorize all the articles they publish into topics like politics, sports, \nentertainment, business, and so on. This allows them to present the news in a more organized and easily accessible way for \ntheir readers or viewers.\n\nTo accomplish this task, text mining techniques such as natural language processing (NLP) and machine learning are used. \nThese techniques can analyze the content of news articles and identify features that are specific to certain topics, \nsuch as keywords, named entities, co-occurring words, part-of-speech tags, and text embeddings. \nBy training a machine learning model on a set of labeled news articles, we can
# ...

# %% [markdown]
# Question 2 (10 points): Write python code to extract these features you discussed above. You can collect a few sample text data for the feature extraction.

# %%
text_data_list = ["Vanessa Hudgens at the 95th Annual Academy Awards held at Ovation Hollywood on March 12, 2023 in Los Angeles, California.",
                  "Best red carpet fashion at the 2023 Oscars",
                  "These companies held money at Silicon Valley Bank and aren’t sure if they’ll recover the funds",
                  "As Twitter failures go from bad to worse, users wonder how long it can stay online",
                  "Snap stock surges as Congress renews efforts to ban TikTok", 
                  "People are shocked and disgusted’: Fox News staffers say they are in the dark amid election lies scandal"]

# %%
# You code here (Please add comments in the code):

import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.util import mark_negation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
nltk.download('stopwords')
nltk.download('opinion_lexicon')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')



# Define stop words and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Define feature extractors
def bag_of_words(text):
    tokens = word_tokenize(text)
    words = [lemmatizer.lemmatize(token.lower()) for token in tokens if token.isalpha() and token.lower() not in stop_words]
    return words

def ngrams(text):
    tokens = word_tokenize(text)
    words = [lemmatizer.lemmatize(token.lower()) for token in tokens if token.isalpha() and token.lower() not in stop_words]
    bigrams = list(nltk.ngrams(words, 2))
    trigrams = list(nltk.ngrams(words, 3))
    return bigrams + trigrams

def pos_tags(text):
    tokens = word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    tags = [tag[1] for tag in pos_tags if tag[0].isalpha() and tag[0].lower() not in stop_words]
    return tags

def sentiment_lexicons(text):
    tokens = word_tokenize(text)
    words = [lemmatizer.lemmatize(token.lower()) for token in tokens if token.isalpha() and token.lower() not in stop_words]
    negated_words = mark_negation(words)
    positive_words = [word for word in negated_words if word in positive_lexicon]
    negative_words = [word for word in negated_words if word in negative_lexicon]
    sentiment_score = len(positive_words) - len(negative_words)
    return sentiment_score

def punctuation(text):
    exclamation_marks = text.count('!')
    question_marks = text.count('?')
    emoticons = len(re.findall(r'(?::|;|=)(?:-)?(?:\)|\(|D|P)', text))
    hashtags = len(re.findall(r'#\w+', text))
    return [exclamation_marks, question_marks, emoticons, hashtags]

# Load sentiment lexicons
positive_lexicon = set(nltk.corpus.opinion_lexicon.positive())
negative_lexicon = set(nltk.corpus.opinion_lexicon.negative())

# Extract features from text data
bow_vectorizer = CountVectorizer(analyzer=bag_of_words)
bow_features = bow_vectorizer.fit_transform(text_data_list)

ngrams_vectorizer = CountVectorizer(analyzer=ngrams)
ngrams_features = ngrams_vectorizer.fit_transform(text_data_list)

pos_vectorizer = CountVectorizer(analyzer=pos_tags)
pos_features = pos_vectorizer.fit_transform(text_data_list)

sentiment_lexicons_features = [sentiment_lexicons(text) for text in text_data_list]

punctuation_features = [punctuation(text) for text in text_data_list]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package opinion_lexicon to /root/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# Question 3 (10 points): Use any of the feature selection methods mentioned in this paper "Deng, X., Li, Y., Weng, J., & Zhang, J. (2019). Feature selection for text classification: A review. Multimedia Tools & Applications, 78(3)." Select the most important features you extracted above, rank the features based on their importance in the descending order.

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
import numpy as np

# Combine all features into one matrix
all_features = []
for i in range(len(text_data_list)):
    features = list(bow_features[i].toarray()[0]) + list(ngrams_features[i].toarray()[0]) + list(pos_features[i].toarray()[0]) + [sentiment_lexicons_features[i]] + punctuation_features[i]
    all_features.append(features)

# Select top 5 features based on Mutual Information
k_best = SelectKBest(mutual_info_classif, k=5)
k_best.fit(all_features, [1, 1, 0, 1, 0, 2])
top_features = [i for i, score in sorted(enumerate(k_best.scores_), key=lambda x: x[1], reverse=True)][:5]
# Print top 5 features and their MI scores
print("Top 5 features based on Mutual Information:")
for feature_index in top_features:
  feature_names = list(bow_vectorizer.get_feature_names_out()) + list(ngrams_vectorizer.get_feature_names_out()) + list(pos_vectorizer.get_feature_names_out()) + list(['sentiment_score', 'exclamation_marks', 'question_marks', 'emoticons', 'hashtags'])
  #feature_names = np.concatenate(bow_vectorizer.get_feature_names_out() + ngrams_vectorizer.get_feature_names_out() + pos_vectorizer.get_feature_names_out() + ['sentiment_score', 'exclamation_marks', 'question_marks', 'emoticons', 'hashtags'])
  print(feature_names[feature_index], k_best.scores_[feature_index])
# Out:
# Top 5 features based on Mutual Information:
# fox 0.7833333333333331
# VBN 0.5166666666666664
# lie 0.48333333333333306
# bad 0.44999999999999973
# carpet 0.44999999999999973

# %% [markdown]
# Question 4 (10 points): Write python code to rank the text based on text similarity. Based on the text data you used for question 2, design a query to match the most relevant docments. Please use the BERT model to represent both your query and the text data, then calculate the cosine similarity between the query and each text in your data. Rank the similary with descending order.

# %%
pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# You code here (Please add comments in the code):


import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Sample text data
text_data = ["Vanessa Hudgens at the 95th Annual Academy Awards held at Ovation Hollywood on March 12, 2023 in Los Angeles, California.",
                  "Best red carpet fashion at the 2023 Oscars",
                  "These companies held money at Silicon Valley Bank and aren’t sure if they’ll recover the funds",
                  "As Twitter failures go from bad to worse, users wonder how long it can stay online",
                  "Snap stock surges as Congress renews efforts to ban TikTok", 
                  "People are shocked and disgusted’: Fox News staffers say they are in the dark amid election lies scandal"]
# Define query
query = "I enjoyed the movie I watched yesterday."

# Load BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Embed query and text data
query_embedding = model.encode([query], convert_to_tensor=True)
text_embeddings = model.encode(text_data, convert_to_tensor=True)

# Calculate cosine similarity between query and text data
similarity_scores = cosine_similarity(query_embedding, text_embeddings)

# Rank text data based on similarity scores
ranked_text_data = sorted(zip(similarity_scores.squeeze().tolist(), text_data), reverse=True)

# Print ranked text data
print("Ranked text data based on similarity to query:")
for score, text in ranked_text_data:
    print(f"Similarity score: {score:.4f}\tText: {text}")
# Out:
# ...
# Ranked text data based on similarity to query:
# Similarity score: 0.4726	Text: Vanessa Hudgens at the 95th Annual Academy Awards held at Ovation Hollywood on March 12, 2023 in Los Angeles, California.
# Similarity score: 0.4494	Text: Best red carpet fashion at the 2023 Oscars
# Similarity score: 0.3218	Text: Snap stock surges as Congress renews efforts to ban TikTok
# Similarity score: 0.3097	Text: As Twitter failures go from bad to worse, users wonder how long it can stay online
# Similarity score: 0.3063	Text: These companies held money at Silicon Valley Bank and aren’t sure if they’ll recover the funds
# Similarity score: 0.2557	Text: People are shocked and disgusted’: Fox News staffers say they are in the dark amid election lies scandal
